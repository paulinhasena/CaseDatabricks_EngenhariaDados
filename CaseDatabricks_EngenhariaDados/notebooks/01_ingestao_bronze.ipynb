# %%
"""           Notebook: Bronze – Portal da Transparência

Objetivo: Realizar a ingestão dos arquivos originais do Portal de Transparência
para a camada Bronze, preservando o formato bruto dos dados em enexo a pipe do case.

Nesta etapa não há transformações de negócio mantenho os dado brutos.
"""

# %%
df = spark.table("default.202510_cpgf")

# %%
from pyspark.sql import functions as F

tabelas_origem = [
    ("default.202510_afastamentos", "bronze_afastamentos"),
    ("default.202507_cadastro", "bronze_cadastro"),
    ("default.202507_remuneracao", "bronze_remuneracao"),
    ("default.202508_cpgf", "bronze_cpgf")
]

for origem, destino in tabelas_origem:

    df = spark.table(origem)

    df_bronze = (
        df.withColumn("ingest_ts", F.current_timestamp())
          .withColumn("source_table", F.lit(origem))
    )

    df_bronze.write \
        .format("delta") \
        .mode("overwrite") \
        .option("overwriteSchema", "true") \
        .saveAsTable(destino)

# %%
spark.table("bronze_cpgf").printSchema()
# Out:
# root
#  |-- codOrgaoSuperior: integer (nullable = true)
#  |-- json: string (nullable = true)
#  |-- ingest_ts: timestamp (nullable = true)
#  |-- source_table: string (nullable = true)

# %%
spark.table("default.bronze_cpgf") \
    .select(F.substring("json", 1, 200).alias("inicio_json")) \
    .show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |inicio_json                                                                                                                                                                                             |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{"id":1,"codOrgaoSuperior":20000,"nomOrgaoSuperior":"Presidência da República","codOrgao":20415,"nomOrgao":"Empresa Brasil de Comunicação","codUnidadeGestora":115406,"nomUnidadeGestora":"EMPRESA BRAS|
# |[{"id":792,"codOrgaoSuperior":22000,"nomOrgaoSuperior":"Ministério da Agricultura e Pecuária","codOrgao":22202,"nomOrgao":"Empresa Brasileira de Pesquisa Agropecuária","codUnidadeGestora":135038,"nomU|
# |[{"id":1203,"codOrgaoSuperior":24000,"nomOrgaoSuperior":"Ministério da Ciência, Tecnologia e Inovaç","codOrgao":20402,"nomOrgao":"Agência Espacial Brasileira","codUnidadeGestora":203001,"nomUnidadeGes|
# |[{"id":1462,"codOrgaoSuperior":25000,"nomOrgaoSuperior":"Ministério da Fazenda","codOrgao":25203,"nomOrgao":"Comissão de Valores Mobiliários","codUnidadeGestora":173030,"nomUnidadeGestora":"COMISSAO D|
# |[{"id":1838,"codOrgaoSuperior":25201,"nomOrgaoSuperior":"Banco Central do Brasil - Orçamento Fiscal e","codOrgao":25201,"nomOrgao":"Banco Central do Brasil - Orçamento Fiscal e Seguridade Social - Uni|
# |[{"id":1942,"codOrgaoSuperior":26000,"nomOrgaoSuperior":"Ministério da Educação","codOrgao":26257,"nomOrgao":"Centro Federal de Educação Tecnológica de Minas Gerais","codUnidadeGestora":153015,"nomUni|
# |[{"id":4551,"codOrgaoSuperior":28000,"nomOrgaoSuperior":"Ministério do Desenvolvimento, Indústria, C","codOrgao":30203,"nomOrgao":"Instituto Nacional de Metrologia, Qualidade e Tecnologia","codUnidade|
